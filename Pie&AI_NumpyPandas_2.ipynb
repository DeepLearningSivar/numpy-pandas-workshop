# %%
import pandas as pd
import seaborn as sns

# %%
pk_df = pd.read_csv('pokemon.csv',index_col=0)

# %%
pk_df.head(10)
# Out:
#                         Name Type 1  Type 2  ...  Speed  Generation  Legendary
# #                                            ...
# 1                  Bulbasaur  Grass  Poison  ...     45           1      False
# 2                    Ivysaur  Grass  Poison  ...     60           1      False
# 3                   Venusaur  Grass  Poison  ...     80           1      False
# 3      VenusaurMega Venusaur  Grass  Poison  ...     80           1      False
# 4                 Charmander   Fire     NaN  ...     65           1      False
# 5                 Charmeleon   Fire     NaN  ...     80           1      False
# 6                  Charizard   Fire  Flying  ...    100           1      False
# 6  CharizardMega Charizard X   Fire  Dragon  ...    100           1      False
# 6  CharizardMega Charizard Y   Fire  Flying  ...    100           1      False
# 7                   Squirtle  Water     NaN  ...     43           1      False
#
# [10 rows x 12 columns]

# %%
pk_df.Name = pk_df.Name.str.replace('.*(?=Mega)','')

# %%
pk_df.head(10)
# Out:
#                Name Type 1  Type 2  ...  Speed  Generation  Legendary
# #                                   ...
# 1         Bulbasaur  Grass  Poison  ...     45           1      False
# 2           Ivysaur  Grass  Poison  ...     60           1      False
# 3          Venusaur  Grass  Poison  ...     80           1      False
# 3     Mega Venusaur  Grass  Poison  ...     80           1      False
# 4        Charmander   Fire     NaN  ...     65           1      False
# 5        Charmeleon   Fire     NaN  ...     80           1      False
# 6         Charizard   Fire  Flying  ...    100           1      False
# 6  Mega Charizard X   Fire  Dragon  ...    100           1      False
# 6  Mega Charizard Y   Fire  Flying  ...    100           1      False
# 7          Squirtle  Water     NaN  ...     43           1      False
#
# [10 rows x 12 columns]

# %%
pk_df.columns = pk_df.columns.str.lower().str.replace(' ','')

# %%
pk_df
# Out:
#                     name    type1   type2  ...  speed  generation  legendary
# #                                          ...
# 1              Bulbasaur    Grass  Poison  ...     45           1      False
# 2                Ivysaur    Grass  Poison  ...     60           1      False
# 3               Venusaur    Grass  Poison  ...     80           1      False
# 3          Mega Venusaur    Grass  Poison  ...     80           1      False
# 4             Charmander     Fire     NaN  ...     65           1      False
# ..                   ...      ...     ...  ...    ...         ...        ...
# 719              Diancie     Rock   Fairy  ...     50           6       True
# 719         Mega Diancie     Rock   Fairy  ...    110           6       True
# 720  HoopaHoopa Confined  Psychic   Ghost  ...     70           6       True
# 720   HoopaHoopa Unbound  Psychic    Dark  ...     80           6       True
# 721            Volcanion     Fire   Water  ...     70           6       True
#
# [800 rows x 12 columns]

# %%
pk_df.columns = pk_df.columns.str.replace('.','_')

# %%
pk_df.sp_atk
# Out:
# #
# 1       65
# 2       80
# 3      100
# 3      122
# 4       60
#       ...
# 719    100
# 719    160
# 720    150
# 720    170
# 721    130
# Name: sp_atk, Length: 800, dtype: int64

# %%
pk_df.head(40)
# Out:
#                 name     type1   type2  ...  speed  generation  legendary
# #                                       ...
# 1          Bulbasaur     Grass  Poison  ...     45           1      False
# 2            Ivysaur     Grass  Poison  ...     60           1      False
# 3           Venusaur     Grass  Poison  ...     80           1      False
# 3      Mega Venusaur     Grass  Poison  ...     80           1      False
# 4         Charmander      Fire     NaN  ...     65           1      False
# 5         Charmeleon      Fire     NaN  ...     80           1      False
# 6          Charizard      Fire  Flying  ...    100           1      False
# 6   Mega Charizard X      Fire  Dragon  ...    100           1      False
# 6   Mega Charizard Y      Fire  Flying  ...    100           1      False
# 7           Squirtle     Water     NaN  ...     43           1      False
# 8          Wartortle     Water     NaN  ...     58           1      False
# 9          Blastoise     Water     NaN  ...     78           1      False
# 9     Mega Blastoise     Water     NaN  ...     78           1      False
# 10          Caterpie       Bug     NaN  ...     45           1      False
# 11           Metapod       Bug     NaN  ...     30           1      False
# 12        Butterfree       Bug  Flying  ...     70           1      False
# 13            Weedle       Bug  Poison  ...     50           1      False
# 14            Kakuna       Bug  Poison  ...     35           1      False
# 15          Beedrill       Bug  Poison  ...     75           1      False
# 15     Mega Beedrill       Bug  Poison  ...    145           1      False
# 16            Pidgey    Normal  Flying  ...     56           1      False
# 17         Pidgeotto    Normal  Flying  ...     71           1      False
# 18           Pidgeot    Normal  Flying  ...    101           1      False
# 18      Mega Pidgeot    Normal  Flying  ...    121           1      False
# 19           Rattata    Normal     NaN  ...     72           1      False
# 20          Raticate    Normal     NaN  ...     97           1      False
# 21           Spearow    Normal  Flying  ...     70           1      False
# 22            Fearow    Normal  Flying  ...    100           1      False
# 23             Ekans    Poison     NaN  ...     55           1      False
# 24             Arbok    Poison     NaN  ...     80           1      False
# 25           Pikachu  Electric     NaN  ...     90           1      False
# 26            Raichu  Electric     NaN  ...    110           1      False
# 27         Sandshrew    Ground     NaN  ...     40           1      False
# 28         Sandslash    Ground     NaN  ...     65           1      False
# 29          Nidoran♀    Poison     NaN  ...     41           1      False
# 30          Nidorina    Poison     NaN  ...     56           1      False
# 31         Nidoqueen    Poison  Ground  ...     76           1      False
# 32          Nidoran♂    Poison     NaN  ...     50           1      False
# 33          Nidorino    Poison     NaN  ...     65           1      False
# 34          Nidoking    Poison  Ground  ...     85           1      False
#
# [40 rows x 12 columns]

# %%
pk_df = pk_df.set_index('name')

# %%
pk_df.head(50)
# Out:
#                      type1   type2  total  ...  speed  generation  legendary
# name                                       ...
# Bulbasaur            Grass  Poison    318  ...     45           1      False
# Ivysaur              Grass  Poison    405  ...     60           1      False
# Venusaur             Grass  Poison    525  ...     80           1      False
# Mega Venusaur        Grass  Poison    625  ...     80           1      False
# Charmander            Fire     NaN    309  ...     65           1      False
# Charmeleon            Fire     NaN    405  ...     80           1      False
# Charizard             Fire  Flying    534  ...    100           1      False
# Mega Charizard X      Fire  Dragon    634  ...    100           1      False
# Mega Charizard Y      Fire  Flying    634  ...    100           1      False
# Squirtle             Water     NaN    314  ...     43           1      False
# Wartortle            Water     NaN    405  ...     58           1      False
# Blastoise            Water     NaN    530  ...     78           1      False
# Mega Blastoise       Water     NaN    630  ...     78           1      False
# Caterpie               Bug     NaN    195  ...     45           1      False
# Metapod                Bug     NaN    205  ...     30           1      False
# Butterfree             Bug  Flying    395  ...     70           1      False
# Weedle                 Bug  Poison    195  ...     50           1      False
# Kakuna                 Bug  Poison    205  ...     35           1      False
# Beedrill               Bug  Poison    395  ...     75           1      False
# Mega Beedrill          Bug  Poison    495  ...    145           1      False
# Pidgey              Normal  Flying    251  ...     56           1      False
# Pidgeotto           Normal  Flying    349  ...     71           1      False
# Pidgeot             Normal  Flying    479  ...    101           1      False
# Mega Pidgeot        Normal  Flying    579  ...    121           1      False
# Rattata             Normal     NaN    253  ...     72           1      False
# Raticate            Normal     NaN    413  ...     97           1      False
# Spearow             Normal  Flying    262  ...     70           1      False
# Fearow              Normal  Flying    442  ...    100           1      False
# Ekans               Poison     NaN    288  ...     55           1      False
# Arbok               Poison     NaN    438  ...     80           1      False
# Pikachu           Electric     NaN    320  ...     90           1      False
# Raichu            Electric     NaN    485  ...    110           1      False
# Sandshrew           Ground     NaN    300  ...     40           1      False
# Sandslash           Ground     NaN    450  ...     65           1      False
# Nidoran♀            Poison     NaN    275  ...     41           1      False
# Nidorina            Poison     NaN    365  ...     56           1      False
# Nidoqueen           Poison  Ground    505  ...     76           1      False
# Nidoran♂            Poison     NaN    273  ...     50           1      False
# Nidorino            Poison     NaN    365  ...     65           1      False
# Nidoking            Poison  Ground    505  ...     85           1      False
# Clefairy             Fairy     NaN    323  ...     35           1      False
# Clefable             Fairy     NaN    483  ...     60           1      False
# Vulpix                Fire     NaN    299  ...     65           1      False
# Ninetales             Fire     NaN    505  ...    100           1      False
# Jigglypuff          Normal   Fairy    270  ...     20           1      False
# Wigglytuff          Normal   Fairy    435  ...     45           1      False
# Zubat               Poison  Flying    245  ...     55           1      False
# Golbat              Poison  Flying    455  ...     90           1      False
# Oddish               Grass  Poison    320  ...     30           1      False
# Gloom                Grass  Poison    395  ...     40           1      False
#
# [50 rows x 11 columns]

# %%
pk_df.isnull().any()
# Out:
# type1         False
# type2          True
# total         False
# hp            False
# attack        False
# defense       False
# sp_atk        False
# sp_def        False
# speed         False
# generation    False
# legendary     False
# dtype: bool

# %%
pk_df
# Out:
#                        type1   type2  total  ...  speed  generation  legendary
# name                                         ...
# Bulbasaur              Grass  Poison    318  ...     45           1      False
# Ivysaur                Grass  Poison    405  ...     60           1      False
# Venusaur               Grass  Poison    525  ...     80           1      False
# Mega Venusaur          Grass  Poison    625  ...     80           1      False
# Charmander              Fire     NaN    309  ...     65           1      False
# ...                      ...     ...    ...  ...    ...         ...        ...
# Diancie                 Rock   Fairy    600  ...     50           6       True
# Mega Diancie            Rock   Fairy    700  ...    110           6       True
# HoopaHoopa Confined  Psychic   Ghost    600  ...     70           6       True
# HoopaHoopa Unbound   Psychic    Dark    680  ...     80           6       True
# Volcanion               Fire   Water    600  ...     70           6       True
#
# [800 rows x 11 columns]

# %%
pk_df.isna().sum()
# Out:
# type1           0
# type2         386
# total           0
# hp              0
# attack          0
# defense         0
# sp_atk          0
# sp_def          0
# speed           0
# generation      0
# legendary       0
# dtype: int64

# %%
pk_df
# Out:
#                        type1   type2  total  ...  speed  generation  legendary
# name                                         ...
# Bulbasaur              Grass  Poison    318  ...     45           1      False
# Ivysaur                Grass  Poison    405  ...     60           1      False
# Venusaur               Grass  Poison    525  ...     80           1      False
# Mega Venusaur          Grass  Poison    625  ...     80           1      False
# Charmander              Fire     NaN    309  ...     65           1      False
# ...                      ...     ...    ...  ...    ...         ...        ...
# Diancie                 Rock   Fairy    600  ...     50           6       True
# Mega Diancie            Rock   Fairy    700  ...    110           6       True
# HoopaHoopa Confined  Psychic   Ghost    600  ...     70           6       True
# HoopaHoopa Unbound   Psychic    Dark    680  ...     80           6       True
# Volcanion               Fire   Water    600  ...     70           6       True
#
# [800 rows x 11 columns]

# %%
pk_df.type2 = pk_df['type2'].fillna('False')

# %%
pk_df.isna().sum()
# Out:
# type1         0
# type2         0
# total         0
# hp            0
# attack        0
# defense       0
# sp_atk        0
# sp_def        0
# speed         0
# generation    0
# legendary     0
# dtype: int64

# %%
pk_df.head(10)
# Out:
#                   type1   type2  total  ...  speed  generation  legendary
# name                                    ...
# Bulbasaur         Grass  Poison    318  ...     45           1      False
# Ivysaur           Grass  Poison    405  ...     60           1      False
# Venusaur          Grass  Poison    525  ...     80           1      False
# Mega Venusaur     Grass  Poison    625  ...     80           1      False
# Charmander         Fire   False    309  ...     65           1      False
# Charmeleon         Fire   False    405  ...     80           1      False
# Charizard          Fire  Flying    534  ...    100           1      False
# Mega Charizard X   Fire  Dragon    634  ...    100           1      False
# Mega Charizard Y   Fire  Flying    634  ...    100           1      False
# Squirtle          Water   False    314  ...     43           1      False
#
# [10 rows x 11 columns]

# %%
pk_df.drop('type2',axis=1,inplace=True)

# %%
pk_df
# Out:
#                        type1  total  hp  ...  speed  generation  legendary
# name                                     ...
# Bulbasaur              Grass    318  45  ...     45           1      False
# Ivysaur                Grass    405  60  ...     60           1      False
# Venusaur               Grass    525  80  ...     80           1      False
# Mega Venusaur          Grass    625  80  ...     80           1      False
# Charmander              Fire    309  39  ...     65           1      False
# ...                      ...    ...  ..  ...    ...         ...        ...
# Diancie                 Rock    600  50  ...     50           6       True
# Mega Diancie            Rock    700  50  ...    110           6       True
# HoopaHoopa Confined  Psychic    600  80  ...     70           6       True
# HoopaHoopa Unbound   Psychic    680  80  ...     80           6       True
# Volcanion               Fire    600  80  ...     70           6       True
#
# [800 rows x 10 columns]

# %%
pk_df.type1.unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pk_df.type1.value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: type1, dtype: int64

# %%
pk_df.describe()
# Out:
#            total          hp      attack  ...      sp_def       speed  generation
# count  800.00000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   435.10250   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    119.96304   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min    180.00000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    330.00000   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    450.00000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    515.00000   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    780.00000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %%
pk_df.corr()
# Out:
#                total        hp    attack  ...     speed  generation  legendary
# total       1.000000  0.618748  0.736211  ...  0.575943    0.048384   0.501758
# hp          0.618748  1.000000  0.422386  ...  0.175952    0.058683   0.273620
# attack      0.736211  0.422386  1.000000  ...  0.381240    0.051451   0.345408
# defense     0.612787  0.239622  0.438687  ...  0.015227    0.042419   0.246377
# sp_atk      0.747250  0.362380  0.396362  ...  0.473018    0.036437   0.448907
# sp_def      0.717609  0.378718  0.263990  ...  0.259133    0.028486   0.363937
# speed       0.575943  0.175952  0.381240  ...  1.000000   -0.023121   0.326715
# generation  0.048384  0.058683  0.051451  ... -0.023121    1.000000   0.079794
# legendary   0.501758  0.273620  0.345408  ...  0.326715    0.079794   1.000000
#
# [9 rows x 9 columns]

# %%
sns.heatmap(pk_df.corr(),annot=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.countplot(pk_df.type1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
